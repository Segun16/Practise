# %% [markdown]
# PERSONAL ML PROJECT

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from sklearn.datasets import load_boston

# %%
Boston_data = load_boston()

# %%
Boston_data.feature_names
# Out:
# array(['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD',
#        'TAX', 'PTRATIO', 'B', 'LSTAT'], dtype='<U7')

# %%
df = pd.DataFrame(Boston_data.data, columns=['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD',
       'TAX', 'PTRATIO', 'B', 'LSTAT'])
df.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
#
#    PTRATIO       B  LSTAT
# 0     15.3  396.90   4.98
# 1     17.8  396.90   9.14
# 2     17.8  392.83   4.03
# 3     18.7  394.63   2.94
# 4     18.7  396.90   5.33

# %%
print(Boston_data['DESCR'])
# Out:
# .. _boston_dataset:
#
# Boston house prices dataset
# ---------------------------
#
# **Data Set Characteristics:**
#
#     :Number of Instances: 506
#
#     :Number of Attributes: 13 numeric/categorical predictive. Median Value (attribute 14) is usually the target.
#
#     :Attribute Information (in order):
#         - CRIM     per capita crime rate by town
#         - ZN       proportion of residential land zoned for lots over 25,000 sq.ft.
#         - INDUS    proportion of non-retail business acres per town
#         - CHAS     Charles River dummy variable (= 1 if tract bounds river; 0 otherwise)
#         - NOX      nitric oxides concentration (parts per 10 million)
#         - RM       average number of rooms per dwelling
#         - AGE      proportion of owner-occupied units built prior to 1940
#         - DIS      weighted distances to five Boston employment centres
#         - RAD      index of accessibility to radial highways
# ...

# %%
df['Price']=Boston_data.target

# %%
df.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
#
#    PTRATIO       B  LSTAT  Price
# 0     15.3  396.90   4.98   24.0
# 1     17.8  396.90   9.14   21.6
# 2     17.8  392.83   4.03   34.7
# 3     18.7  394.63   2.94   33.4
# 4     18.7  396.90   5.33   36.2

# %%
df.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.677083   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534  356.674032
# ...

# %%
sns.pairplot(df)

# %%
df.columns
# Out:
# Index(['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX',
#        'PTRATIO', 'B', 'LSTAT', 'Price'],
#       dtype='object')

# %%
df['CRIM'] = df['CRIM']/df['CRIM'].max()

# %%
df['CRIM'].describe()
# Out:
# count    506.000000
# mean       0.040612
# std        0.096672
# min        0.000071
# 25%        0.000922
# 50%        0.002883
# 75%        0.041327
# max        1.000000
# Name: CRIM, dtype: float64

# %%
df['CRIM'].hist()
# Out:
# <AxesSubplot:>

# %%
df.corr()
# Out:
#              CRIM        ZN     INDUS      CHAS       NOX        RM       AGE  \
# CRIM     1.000000 -0.200469  0.406583 -0.055892  0.420972 -0.219247  0.352734
# ZN      -0.200469  1.000000 -0.533828 -0.042697 -0.516604  0.311991 -0.569537
# INDUS    0.406583 -0.533828  1.000000  0.062938  0.763651 -0.391676  0.644779
# CHAS    -0.055892 -0.042697  0.062938  1.000000  0.091203  0.091251  0.086518
# NOX      0.420972 -0.516604  0.763651  0.091203  1.000000 -0.302188  0.731470
# RM      -0.219247  0.311991 -0.391676  0.091251 -0.302188  1.000000 -0.240265
# AGE      0.352734 -0.569537  0.644779  0.086518  0.731470 -0.240265  1.000000
# DIS     -0.379670  0.664408 -0.708027 -0.099176 -0.769230  0.205246 -0.747881
# RAD      0.625505 -0.311948  0.595129 -0.007368  0.611441 -0.209847  0.456022
# TAX      0.582764 -0.314563  0.720760 -0.035587  0.668023 -0.292048  0.506456
# PTRATIO  0.289946 -0.391679  0.383248 -0.121515  0.188933 -0.355501  0.261515
# ...

# %%
X = df[['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX',
       'PTRATIO', 'B', 'LSTAT']]
y = df['Price']

# %%
from sklearn.linear_model import LinearRegression
lm = LinearRegression()

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4)

# %%
lm.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
print(X_train.shape,X_test.shape, y_train.shape,y_test.shape)
# Out:
# (303, 13) (203, 13) (303,) (203,)

# %%
Predictions=lm.predict(X_test)

# %%
plt.scatter(y_test,Predictions)

# %%
sns.regplot(y_test,Predictions)
# Out:
# C:\Users\LENOVO THINKPAD YOGA\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Price'>

# %%
lm.coef_
# Out:
# array([-6.91145822e+00,  4.09900485e-02,  1.20264387e-02,  2.85449084e+00,
#        -2.05958702e+01,  3.81269300e+00, -9.12775641e-04, -1.62889963e+00,
#         2.92089754e-01, -1.05961581e-02, -9.08216524e-01,  6.24241740e-03,
#        -5.70800360e-01])

# %%
lm.intercept_
# Out:
# 39.17379325935183

# %%
sns.distplot((y_test - Predictions))
# Out:
# C:\Users\LENOVO THINKPAD YOGA\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Price', ylabel='Density'>

# %%
dict = {'y_test': y_test, 'Predictions': Predictions}
view = pd.DataFrame(dict)
view.head(20)
# Out:
#      y_test  Predictions
# 17     17.5    16.841366
# 217    28.7    28.243265
# 277    33.1    35.186973
# 426    10.2    18.163614
# 194    29.1    31.606475
# 318    23.1    24.364171
# 191    30.5    30.358599
# 190    37.0    30.864579
# 85     26.6    28.152758
# 206    24.4    23.733070
# 432    16.1    23.058827
# 314    23.8    25.559485
# 312    19.4    23.353440
# 87     22.2    26.262024
# 215    25.0    24.711216
# 0      24.0    30.100014
# 139    17.8    16.411589
# 89     28.7    31.285657
# 241    20.1    23.380336
# 235    24.0    25.402171

# %%
lm.score(X_test,y_test)
# Out:
# 0.7736599998268537

# %%
from sklearn import metrics

# %%
print('MSE:', metrics.mean_squared_error(y_test,Predictions))
print('MAE:', metrics.mean_absolute_error(y_test,Predictions))
print('RMSE:', np.sqrt( metrics.mean_squared_error(y_test,Predictions)))
# Out:
# MSE: 16.963378967438103
# MAE: 3.1000060650599885
# RMSE: 4.11866227887625

# %%
file = "C:\Users\LENOVO THINKPAD YOGA\Desktop\Refactored_Py_DS_ML_Bootcamp-master\11-Linear-Regression\Ecommerce Customers.csv"
# Out:
#   File "<ipython-input-125-a7f949b84f46>", line 1
#     file = "C:\Users\LENOVO THINKPAD YOGA\Desktop\Refactored_Py_DS_ML_Bootcamp-master\11-Linear-Regression\Ecommerce Customers.csv"
#            ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape

# %%
df1 = pd.read_csv(r"C:\Users\LENOVO THINKPAD YOGA\Desktop\Refactored_Py_DS_ML_Bootcamp-master\11-Linear-Regression\Ecommerce Customers.csv")

# %%
df1.head()
# Out:
#                            Email  \
# 0      mstephenson@fernandez.com
# 1              hduke@hotmail.com
# 2               pallen@yahoo.com
# 3        riverarebecca@gmail.com
# 4  mstephens@davidson-herman.com
#
#                                              Address            Avatar  \
# 0       835 Frank Tunnel\nWrightmouth, MI 82180-9605            Violet
# 1     4547 Archer Common\nDiazchester, CA 06566-8576         DarkGreen
# 2  24645 Valerie Unions Suite 582\nCobbborough, D...            Bisque
# 3   1414 David Throughway\nPort Jason, OH 22070-1220       SaddleBrown
# 4  14023 Rodriguez Passage\nPort Jacobville, PR 3...  MediumAquaMarine
#
#    Avg. Session Length  Time on App  Time on Website  Length of Membership  \
# 0            34.497268    12.655651        39.577668              4.082621
# 1            31.926272    11.109461        37.268959              2.664034
# 2            33.000915    11.330278        37.110597              4.104543
# ...

# %%
df1.corr()
# Out:
#                       Avg. Session Length  Time on App  Time on Website  \
# Avg. Session Length              1.000000    -0.027826        -0.034987
# Time on App                     -0.027826     1.000000         0.082388
# Time on Website                 -0.034987     0.082388         1.000000
# Length of Membership             0.060247     0.029143        -0.047582
# Yearly Amount Spent              0.355088     0.499328        -0.002641
#
#                       Length of Membership  Yearly Amount Spent
# Avg. Session Length               0.060247             0.355088
# Time on App                       0.029143             0.499328
# Time on Website                  -0.047582            -0.002641
# Length of Membership              1.000000             0.809084
# Yearly Amount Spent               0.809084             1.000000

# %%
df1.columns
# Out:
# Index(['Email', 'Address', 'Avatar', 'Avg. Session Length', 'Time on App',
#        'Time on Website', 'Length of Membership', 'Yearly Amount Spent'],
#       dtype='object')

# %%
df1['Avg. Session Length'].max()
df1['Avg. Session Length'].min()
# Out:
# 29.532428967057943

# %%
df1.describe()
# Out:
#        Avg. Session Length  Time on App  Time on Website  \
# count           500.000000   500.000000       500.000000
# mean             33.053194    12.052488        37.060445
# std               0.992563     0.994216         1.010489
# min              29.532429     8.508152        33.913847
# 25%              32.341822    11.388153        36.349257
# 50%              33.082008    11.983231        37.069367
# 75%              33.711985    12.753850        37.716432
# max              36.139662    15.126994        40.005182
#
#        Length of Membership  Yearly Amount Spent
# count            500.000000           500.000000
# mean               3.533462           499.314038
# std                0.999278            79.314782
# min                0.269901           256.670582
# 25%                2.930450           445.038277
# 50%                3.533975           498.887875
# 75%                4.126502           549.313828
# max                6.922689           765.518462

# %%
bins = (df1['Avg. Session Length'].max()-df1['Avg. Session Length'].min())/4
bins
# Out:
# 1.6518083804331445

# %%
Range = np.arange(df1['Avg. Session Length'].min(),df1['Avg. Session Length'].max(),bins)
Range
# Out:
# array([29.53242897, 31.18423735, 32.83604573, 34.48785411])

# %%
values = ['Low', 'Medium', 'High']

# %%
df1['Avg. Session Length'].hist(bins=3)
# Out:
# <AxesSubplot:>

# %%
df['Avg. Session Binned'] = pd.cut(df1['Avg. Session Length'],Range, labels=values,include_lowest=True)

# %%
df['Avg. Session Binned'].head(20)
# Out:
# 0        NaN
# 1     Medium
# 2       High
# 3       High
# 4       High
# 5       High
# 6     Medium
# 7     Medium
# 8       High
# 9     Medium
# 10      High
# 11      High
# 12       Low
# 13      High
# 14    Medium
# 15       Low
# 16    Medium
# 17    Medium
# 18    Medium
# 19    Medium
# Name: Avg. Session Binned, dtype: category
# Categories (3, object): ['Low' < 'Medium' < 'High']

# %%
sns.pairplot(df1)

# %%
sns.scatterplot( df1['Yearly Amount Spent'],df1['Time on Website'])
# Out:
# C:\Users\LENOVO THINKPAD YOGA\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Yearly Amount Spent', ylabel='Time on Website'>

# %%
sns.jointplot(data=df1, x= df1['Yearly Amount Spent'], y= df1['Time on Website'])

# %%
sns.regplot(data=df1, y= df1['Yearly Amount Spent'], x= df1['Time on App'])
# Out:
# <AxesSubplot:xlabel='Time on App', ylabel='Yearly Amount Spent'>

# %%
X = df1[['Avg. Session Length', 'Time on App','Time on Website', 'Length of Membership']]
y = df1['Yearly Amount Spent']

# %%
from sklearn.model_selection import train_test_split

# %%
 X_train, X_test, y_train, y_test = train_test_split( X, y, test_size=0.33)

# %%
from sklearn.linear_model import LinearRegression

# %%
lm = LinearRegression()

# %%
lm.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
Prediction = lm.predict(X_test)

# %%
lm.score(X_test,y_test)
# Out:
# 0.9850446336760897

# %%
sns.scatterplot(y_test,Prediction)
# Out:
# C:\Users\LENOVO THINKPAD YOGA\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Yearly Amount Spent'>

# %%
sns.distplot((y_test-Prediction))
# Out:
# C:\Users\LENOVO THINKPAD YOGA\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Yearly Amount Spent', ylabel='Density'>

# %%
lm.coef_
# Out:
# array([25.4889117 , 38.9431313 ,  0.94403041, 61.74983447])

# %%
lm.intercept_
# Out:
# -1065.523186032883

# %%
Df = pd.DataFrame(lm.coef_,X.columns, columns=['Coefficient'])
Df
# Out:
#                       Coefficient
# Avg. Session Length     25.488912
# Time on App             38.943131
# Time on Website          0.944030
# Length of Membership    61.749834

# %%
from sklearn import metrics

# %%
print('MSE :', metrics.mean_squared_error(y_test,Prediction))
print('MAE :', metrics.mean_absolute_error(y_test,Prediction))
print('SMSE :', np.sqrt(metrics.mean_squared_error(y_test,Prediction)))
# Out:
# MSE : 96.79953090497929
# MAE : 7.658542143444203
# SMSE : 9.838675261689415
